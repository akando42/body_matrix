# %%
from body_matrix import load
from body_matrix import infer
from body_matrix import process
from body_matrix import draw

video, frame_counts, fps, sample_frame = load.video(
    "/Users/troydo42/Desktop/Body_Matrixes/samples/man_02.mp4", 
    90, 
    1
)

keypoints_model, keypoints_transform = load.keypoints_model("cpu")
boxes, keypoints = infer.detect_main_target(
    sample_frame, "cpu", 0.8, keypoints_model, keypoints_transform
)

selected_kps = process.keypoints_filter(
    ['nose','left_shoulder','right_shoulder'], 
    keypoints
)
# Out:
# Found  1  person in the frame
# Distances:  [5.0128936767578125]
# Areas:  [81433.2939823335]
# FOCUSES:  [16244.767839361413]
# Select keypoint index 0

# %%
selected_kps
# Out:
# {'nose': [292.3323059082031, 534.0706176757812],
#  'left_shoulder': [392.7712707519531, 716.343994140625],
#  'right_shoulder': [314.333251953125, 717.3033447265625]}

# %%
for index, value in enumerate(selected_kps.values()):
    print(index, value)
# Out:
# 0 [292.3323059082031, 534.0706176757812]
# 1 [392.7712707519531, 716.343994140625]
# 2 [314.333251953125, 717.3033447265625]

# %%
output = draw.keypoint_markers(
    coordinates=selected_kps,
    image=sample_frame, 
    label_font="/Users/troydo42/Desktop/Body_Matrixes/Roboto-Bold.ttf"
)

output
# Out:
# [292.3323059082031, 534.0706176757812]
# [392.7712707519531, 716.343994140625]
# [314.333251953125, 717.3033447265625]
# <PIL.Image.Image image mode=RGB size=720x1280 at 0x106DF1208>
