# %% [markdown]
# Install packages

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install body-matrix==0.3.5
# Out:
# ...
#   Attempting uninstall: body-matrix
#     Found existing installation: body-matrix 0.2.8
#     Uninstalling body-matrix-0.2.8:
#       Successfully uninstalled body-matrix-0.2.8
# ...
# WARNING: You are using pip version 22.0.4; however, version 23.0.1 is available.
# You should consider upgrading via the '/anaconda3/bin/python -m pip install --upgrade pip' command.

# %%
# !pip install av
# Out:
# ...
# WARNING: You are using pip version 22.0.4; however, version 23.0.1 is available.
# You should consider upgrading via the '/anaconda3/bin/python -m pip install --upgrade pip' command.

# %% [markdown]
# Load Video, Detection and Segmentation Models

# %%
from body_matrix import load, infer, process, score, draw, export

keypoints_model, keypoints_transform = load.keypoints_model("cpu")
segment_model, segment_transforms = load.segment_model("cpu")
video, frame_counts, fps, sample_frame = load.video(
    "/Users/troydo42/Desktop/Raw_Vids/VID_20230109_152119~2.mp4", 
    -90, 
    1
)

# %%
pixelated = draw.pixelate(sample_frame, 10)
pixelated
# Out:
# <PIL.Image.Image image mode=RGB size=1088x1920 at 0x1A51FE0278>

# %%
from PIL import Image
import numpy as np

def add_crown_score_to_frame(frame):
    selected_box, keypoints = infer.detect_main_target(
        frame, "cpu", 0.8, keypoints_model, keypoints_transform
    )

    mask, mask_image, bool_mask = infer.segment_selected_target(
        frame, "cpu", selected_box, 0.99, segment_model, segment_transforms
    )

    selected_kps = process.keypoints_filter(
        [
            'left_ear', 'right_ear',
            'left_shoulder','right_shoulder',
            'left_wrist','right_wrist',
            'left_hip', 'right_hip',
            'left_ankle', 'right_ankle'
        ],  
        keypoints
    )

    segment_contours = process.segmentation_contour(
        frame, 
        bool_mask
    )

    scores, measures = score.frame_SHA_score(
        frame, bool_mask, selected_kps
    )

    pixelated = draw.pixelate(frame, 21)
    top_left = (int(selected_box[0]), int(selected_box[1]))
    selected_person = frame.crop(selected_box)
    pixelated.paste(
        selected_person,
        top_left
    )

    top_head = process.find_tophead_point(
        selected_kps['left_ear'],
        selected_kps['right_ear'],
        segment_contours
    )

    crowned_frame = draw.add_crown(
        score=scores, 
        le=selected_kps['left_shoulder'], 
        re=selected_kps['right_shoulder'], 
        top_head=top_head, 
        frame=pixelated,
        crown_image="/content/drive/MyDrive/Body_Matrix/crown.png",
        font_file="/content/drive/MyDrive/Body_Matrix/Roboto-Bold.ttf"
    )

    return crowned_frame

# %%
add_crown_score_to_frame(sample_frame)
# Out:
# Found  2  person in the frame
# Distances:  [7.69439697265625, 171.95331573486328]
# Areas:  [171038.45408160985, 190748.63233516412]
# FOCUSES:  [22228.9615013929, 1109.3047640284037]
# Select keypoint index 0
# Found  2  person in the frame
# [229.73158264160156, 502.0272521972656, 495.2856750488281, 1312.7774658203125]
# [440.4559326171875, 527.090576171875, 662.932861328125, 1295.8824462890625]
# [449.0971984863281, 534.2400512695312, 661.0555419921875, 1312.140380859375]
# [440.4559326171875, 527.090576171875, 662.932861328125, 1295.8824462890625]
# [189.229847437818, 12.182546942944109]
# 12.182546942944109 1
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-11-50e3d1b8f216> in <module>
# ----> 1 add_crown_score_to_frame(sample_frame)
#
# <ipython-input-10-29e5155ebfc9> in add_crown_score_to_frame(frame)
#      52         frame=pixelated,
# ...

# %%
from torchvision.transforms.functional import to_pil_image

pil_crowned_frames = []
for index, vid_frame in enumerate(video):
    print("processing frame ", index, " of ", frame_counts)
    frame = to_pil_image(vid_frame)
    frame = frame.rotate(-90, expand=True)
    pil_crowned = add_crown_score_to_frame(frame)
    pil_crowned_frames.append(pil_crowned)

# %%
export.generate_instagram_vid(
    vid_name="lottee_daotan_westgirl.mp4", 
    vid_width = sample_frame.width, 
    vid_height = sample_frame.height, 
    pil_images = pil_crowned_frames, 
    stop_index=int(frame_counts/2), 
    fps=fps, 
    repeat_rate=2, 
    slow_motion_rate=1
)
